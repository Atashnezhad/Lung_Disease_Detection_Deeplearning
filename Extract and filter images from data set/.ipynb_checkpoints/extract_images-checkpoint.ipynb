# %%
import pandas as pd
import os
import shutil
import sys

# %%
FILE_PATH = "C:/Users/DASLAB Hareland 3/Desktop/covid-chestxray-dataset/metadata.csv"
IMAGES_PATH = "C:/Users/DASLAB Hareland 3/Desktop/covid-chestxray-dataset/images"

# %%
df = pd.read_csv(FILE_PATH)
df.shape
# Out:
# (950, 30)

# %%
print(df.head(1))
# Out:
#   patientid  offset sex   age                   finding RT_PCR_positive  \
# 0         2     0.0   M  65.0  Pneumonia/Viral/COVID-19               Y
#
#   survival intubated intubation_present went_icu  ...              date  \
# 0        Y         N                  N        N  ...  January 22, 2020
#
#                                       location  folder  \
# 0  Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
#
#                                             filename                   doi  \
# 0  auntminnie-a-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
#
#                                                  url  license  \
# 0  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
#
#                                       clinical_notes other_notes Unnamed: 29
# 0  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
#
# [1 rows x 30 columns]

# %%
df['finding'].value_counts(normalize=True)
# Out:
# Pneumonia/Viral/COVID-19                   0.614737
# todo                                       0.087368
# Pneumonia                                  0.085263
# Pneumonia/Fungal/Pneumocystis              0.031579
# No Finding                                 0.023158
# Pneumonia/Bacterial/Streptococcus          0.023158
# Tuberculosis                               0.018947
# Pneumonia/Viral/SARS                       0.016842
# Pneumonia/Lipoid                           0.013684
# Pneumonia/Bacterial/Mycoplasma             0.011579
# Pneumonia/Bacterial/Legionella             0.010526
# Pneumonia/Bacterial/Klebsiella             0.010526
# Pneumonia/Viral/MERS-CoV                   0.010526
# Pneumonia/Bacterial/Nocardia               0.008421
# Pneumonia/Viral/Varicella                  0.006316
# Pneumonia/Viral/Influenza                  0.005263
# Pneumonia/Bacterial                        0.004211
# Pneumonia/Bacterial/E.Coli                 0.004211
# ...

# %%
# df['finding'].value_counts(normalize=True).plot.pie()

# Finding distribution (nan if unknown)
ax = df['finding'].value_counts(dropna=False).\
                            plot.pie(y='Finding', legend = True, 
                                     autopct='%2.0f%%', 
                                     figsize = (15,15), 
                                     title = 'Finding Distribution')

# %%
df['view'].unique()
# Out:
# array(['PA', 'AP', 'L', 'Axial', 'AP Supine', 'Coronal', 'AP Erect'],
#       dtype=object)

# %%
df['view'].value_counts(normalize=True)
# Out:
# PA           0.362105
# AP Supine    0.246316
# AP           0.213684
# L            0.088421
# Axial        0.071579
# Coronal      0.016842
# AP Erect     0.001053
# Name: view, dtype: float64

# %% [markdown]
# ### Extract Covid cases from base data
#
# make a new folder and name it data set.

# %%
TARGET_DIR = "Dataset/Covid"

if not os.path.exists(TARGET_DIR):
    os.makedirs(TARGET_DIR)
    print("Covid folder created")

# %%
cnt = 0
for (i,row) in df.iterrows():
    if row['finding'] == "Pneumonia/Viral/COVID-19" and row['view'] == "PA":
        
        filename = row['filename']
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print('moving image', cnt)
        cnt += 1
print(cnt)
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# moving image 21
# moving image 22
# moving image 23
# moving image 24
# moving image 25
# moving image 26
# moving image 27
# moving image 28
# moving image 29
# moving image 30
# moving image 31
# moving image 32
# moving image 33
# moving image 34
# moving image 35
# moving image 36
# moving image 37
# moving image 38
# moving image 39
# moving image 40
# moving image 41
# moving image 42
# moving image 43
# moving image 44
# moving image 45
# moving image 46
# moving image 47
# moving image 48
# moving image 49
# moving image 50
# moving image 51
# moving image 52
# moving image 53
# moving image 54
# moving image 55
# ...

# %% [markdown]
# ### Extract Pneumocystis cases from base data
#
# make a new folder and name it data set.

# %%
TARGET_DIR = "Dataset/Pneumocystis"

if not os.path.exists(TARGET_DIR):
    os.makedirs(TARGET_DIR)
    print("Pneumocystis folder created")
# Out:
# Pneumocystis folder created

# %%
cnt = 0
for (i,row) in df.iterrows():
    if row['finding'] == "Pneumonia/Fungal/Pneumocystis" and row['view'] == "PA":
        
        filename = row['filename']
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print('moving image', cnt)
        cnt += 1
print(cnt)
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# 21

# %% [markdown]
# ### Extract Streptococcus cases from base data
#
# make a new folder and name it data set.

# %%
TARGET_DIR = "Dataset/Streptococcus"

if not os.path.exists(TARGET_DIR):
    os.makedirs(TARGET_DIR)
    print("Streptococcus folder created")
# Out:
# Streptococcus folder created

# %%
cnt = 0
for (i,row) in df.iterrows():
    if row['finding'] == "Pneumonia/Bacterial/Streptococcus" and row['view'] == "PA":
        
        filename = row['filename']
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print('moving image', cnt)
        cnt += 1
print(cnt)
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# 12

# %% [markdown]
# ### Extract Normal cases from Kaggle Chest X-Ray Images (Pneumonia) data

# %%
import random

# %%
TARGET_NORMAL_DIR = "Dataset/NORMAL"

if not os.path.exists(TARGET_NORMAL_DIR):
    os.makedirs(TARGET_NORMAL_DIR)
    print("NORMAL folder created")
# Out:
# NORMAL folder created

# %%
# inserting the parent directory into current path
# sys.path.insert(1, '../COVID_19/Dataset/')
# /Users/amin/Downloads/COVID_19/Dataset

# %%
# KAGGLE_FILE_PATH = '/Users/amin/Downloads/chest_xray/train/NORMAL'
# TARGET_NORMAL_DIR = '/Users/amin/Downloads/COVID_19/Dataset/NORMAL/'
# TARGET_Covid_DIR = '/Users/amin/Downloads/COVID_19/Dataset/Covid/'

# %% [markdown]
# check out the number of covid images and select same number from normal images and add it to the data set / normal fodler

# %%
TARGET_Covid_DIR = 'Dataset/Covid'
Number_of_Covid_imgs = os.listdir(TARGET_Covid_DIR)
print('Number_of_Covid_imgs = ', len(Number_of_Covid_imgs))
# Out:
# Number_of_Covid_imgs =  196

# %%
KAGGLE_FILE_PATH = 'C:/Users/DASLAB Hareland 3/Downloads/chest_xray/chest_xray/train/NORMAL'
Number_of_Normal_imgs_in_kaggle_df = os.listdir(KAGGLE_FILE_PATH)
print('Number_of_Normal_imgs_in_kaggle_df = ', len(Number_of_Normal_imgs_in_kaggle_df))
# Out:
# Number_of_Normal_imgs_in_kaggle_df =  1342

# %%
random.shuffle(Number_of_Normal_imgs_in_kaggle_df)

# %%
TARGET_NORMAL_DIR = 'Dataset/NORMAL'

for i in range(len(Number_of_Covid_imgs)):
    image_name = Number_of_Normal_imgs_in_kaggle_df[i]
    image_path = os.path.join(KAGGLE_FILE_PATH, image_name)
    
    target_path = os.path.join(TARGET_NORMAL_DIR, image_name)
    shutil.copy2(image_path, target_path)
    print(f"copying image {i}")
# Out:
# copying image 0
# copying image 1
# copying image 2
# copying image 3
# copying image 4
# copying image 5
# copying image 6
# copying image 7
# copying image 8
# copying image 9
# copying image 10
# copying image 11
# copying image 12
# copying image 13
# copying image 14
# copying image 15
# copying image 16
# copying image 17
# copying image 18
# copying image 19
# copying image 20
# copying image 21
# copying image 22
# copying image 23
# copying image 24
# copying image 25
# copying image 26
# copying image 27
# copying image 28
# copying image 29
# copying image 30
# copying image 31
# copying image 32
# copying image 33
# copying image 34
# copying image 35
# copying image 36
# copying image 37
# copying image 38
# copying image 39
# copying image 40
# copying image 41
# copying image 42
# copying image 43
# copying image 44
# copying image 45
# copying image 46
# copying image 47
# copying image 48
# copying image 49
# copying image 50
# copying image 51
# copying image 52
# ...

# %% [markdown]
# ### Now we have a data set of four classes including Normal, Pneumocystis, Streptococcus, and Covid positive.
