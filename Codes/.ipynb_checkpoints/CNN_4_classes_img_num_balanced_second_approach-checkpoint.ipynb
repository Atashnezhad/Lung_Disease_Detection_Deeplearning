# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import os
import shutil
import sys
import warnings
warnings.filterwarnings('ignore')
from collections import Counter
import random

import numpy as np
import matplotlib.pyplot as plt
# import tensorflow as tf
from tensorflow import keras
import tensorflow

from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# %% [markdown]
# ### Check out the directories

# %%
# inserting the parent directory into current path
sys.path.insert(1, '../COVID_19/')

# %%
os.listdir('../Dataset_4_classe/')
# Out:
# ['.DS_Store', 'Train', 'Val']

# %%
os.listdir('../Dataset_4_classe/Train/')
# Out:
# ['.DS_Store', 'Pneumocystis', 'NORMAL', 'Streptococcus', 'Covid']

# %%
Train_NORMAL = os.listdir('../Dataset_4_classe_second_approach/Train/NORMAL/')
print('Train_NORMAL = ', len(Train_NORMAL))

Train_Pneumocystis = os.listdir('../Dataset_4_classe_second_approach/Train/Pneumocystis/')
print('Train_Pneumocystis = ', len(Train_Pneumocystis))

Train_Streptococcus = os.listdir('../Dataset_4_classe_second_approach/Train/Streptococcus/')
print('Train_Streptococcus = ', len(Train_Streptococcus))

Train_Covid = os.listdir('../Dataset_4_classe_second_approach/Train/Covid/')
print('Train_Covid = ', len(Train_Covid))
# Out:
# Train_NORMAL =  176
# Train_Pneumocystis =  194
# Train_Streptococcus =  187
# Train_Covid =  176

# %%
Val_NORMAL = os.listdir('../Dataset_4_classe_second_approach/Val/NORMAL/')
print('Val_NORMAL = ', len(Val_NORMAL))

Val_Pneumocystis = os.listdir('../Dataset_4_classe_second_approach/Val/Pneumocystis/')
print('Val_Pneumocystis = ', len(Val_Pneumocystis))

Val_Streptococcus = os.listdir('../Dataset_4_classe_second_approach/Val/Streptococcus/')
print('Val_Streptococcus = ', len(Val_Streptococcus))

Val_Covid = os.listdir('../Dataset_4_classe_second_approach/Val/Covid/')
print('Val_Covid = ', len(Val_Covid))
# Out:
# Val_NORMAL =  16
# Val_Pneumocystis =  16
# Val_Streptococcus =  16
# Val_Covid =  16

# %% [markdown]
# ## Quick look to the images

# %%
print('Images_names \n ', 
      Train_NORMAL[0], '\n' ,
      Train_Covid[0], '\n' ,
      Train_Pneumocystis[0], '\n' , 
      Train_Streptococcus[1])
# Out:
# Images_names
#   NORMAL2-IM-1056-0001.jpeg
#  f6d980a0.jpg
#  Pneumocystis_0_3895.jpeg
#  Streptococcus_0_2252.jpeg

# %%
# ref https://www.kaggle.com/feyzazkefe/pneumonia-detection-using-cnn-89-42-acc

img_name = Train_NORMAL[0]
img_normal = load_img('../Dataset_4_classe_second_approach/Train/NORMAL/' + img_name)

img_name_1 = Train_Covid[0]
img_Covid = load_img('../Dataset_4_classe_second_approach/Train/Covid/' + img_name_1)

img_name_2 = Train_Pneumocystis[0]
img_Pneumocystis = load_img('../Dataset_4_classe_second_approach/Train/Pneumocystis/' + img_name_2)

img_name_3 = Train_Streptococcus[1]
img_Streptococcus = load_img('../Dataset_4_classe_second_approach/Train/Streptococcus/' + img_name_3)



fig, axs = plt.subplots(1,4,figsize=(17,10))
axs[0].imshow(img_normal)
axs[0].set_title("NORMAL")

axs[1].imshow(img_Covid)
axs[1].set_title("Covid");


axs[2].imshow(img_Pneumocystis)
axs[2].set_title("Pneumocystis")

axs[3].imshow(img_Streptococcus)
axs[3].set_title("Streptococcus");


plt.savefig("../Assets/plot_01_assets_1_4classes_second_app.png")

# %% [markdown]
# ### Assemble CNN model

# %%
model = Sequential()
activ = 'sigmoid'

model.add(Conv2D(32, kernel_size=(3,3),
                 activation=activ,
                 input_shape=(224,224,3)))
model.add(BatchNormalization())


model.add(Conv2D(64, kernel_size=(3,3),
                 activation=activ))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))



model.add(Conv2D(64, kernel_size=(3,3),
                 activation=activ))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))


# model.add(Conv2D(64, kernel_size=(3,3),
#                  activation=activ))
# model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2,2)))
# model.add(Dropout(0.25))



model.add(Conv2D(128, kernel_size=(3,3),
                 activation=activ))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))



model.add(Flatten())
model.add(Dense(64, activation=activ))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))
# Out:
# WARNING:tensorflow:From /Users/amin/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/amin/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %% [markdown]
# ### Metrics

# %%
# metr_auc = tensorflow.keras.metrics.AUC(num_thresholds=200, curve='ROC')
# TP = tensorflow.keras.metrics.TruePositives(thresholds=None, name=None, dtype=None)
# TN = tensorflow.keras.metrics.TrueNegatives(thresholds=None, name=None, dtype=None)
# FP = tensorflow.keras.metrics.FalsePositives(thresholds=None, name=None, dtype=None)
# FN = tensorflow.keras.metrics.FalseNegatives(thresholds=None, name=None, dtype=None)

# Recall_metr = tensorflow.keras.metrics.Recall(thresholds=None, top_k=None, 
#                 class_id=None, name=None, dtype=None)
# mtr_list = ['accuracy','mse', metr_auc,TP,TN,FP,FN]
mtr_list = ['accuracy']

# %% [markdown]
# any time that you have several images (multiclass classification), use two to three convolution layers.
# Also,a use softmax as activation for the last layer as I did above (my recommendation but you may test other types either).
# Note that the categorical_crossentropy isalmost default for multiclass classifiers.
#
# remember that we always use convolution layers for images. the reason is if we use dense layers we will lose positional information in images.

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer='rmsprop', 
              metrics=mtr_list)

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# batch_normalization_v1 (Batc (None, 222, 222, 32)      128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 220, 220, 64)      18496
# _________________________________________________________________
# batch_normalization_v1_1 (Ba (None, 220, 220, 64)      256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 110, 110, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 64)      36928
# _________________________________________________________________
# batch_normalization_v1_2 (Ba (None, 108, 108, 64)      256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# batch_normalization_v1_3 (Ba (None, 52, 52, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 86528)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                5537856
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 5,669,444
# Trainable params: 5,668,868
# Non-trainable params: 576
# _________________________________________________________________

# %% [markdown]
# ### Prepare the data
#
# * Resacle function does normalization.
# * Augment the data set for both train and val.
# * Then use flow to apply the data augmention.
# * Here we use balanced data from previous step.

# %%
train_datagen = image.ImageDataGenerator(
                featurewise_center=False, samplewise_center=False,
                featurewise_std_normalization=False, samplewise_std_normalization=False,
                zca_whitening=False, zca_epsilon=1e-06, rotation_range=0, width_shift_range=0.0,
                height_shift_range=0.0, brightness_range=None, shear_range=0.2, zoom_range=0.2,
                channel_shift_range=0.0, fill_mode='nearest', cval=0.0,
                horizontal_flip=True, vertical_flip=False, rescale=1./255,
                preprocessing_function=None, data_format=None, validation_split=0.0, dtype=None)

# %% [markdown]
# for val data set just apply rescale function.

# %%
val_dataset = image.ImageDataGenerator(rescale=1./255)

# %% [markdown]
# # Flow data

# %%
train_generator = train_datagen.flow_from_directory(
                    directory='../Dataset_4_classe_second_approach/Train/',
                    target_size=(224,224),
                    color_mode="rgb",
                    classes=None,
                    class_mode="categorical",
                    batch_size=32,
                    shuffle=True,
                    seed=1234,
                    save_to_dir=None,
                    save_prefix="",
                    save_format="png",
                    follow_links=False,
                    subset=None,
                    interpolation="nearest")
# Out:
# Found 733 images belonging to 4 classes.

# %%
train_generator.class_indices
# Out:
# {'Covid': 0, 'NORMAL': 1, 'Pneumocystis': 2, 'Streptococcus': 3}

# %%
validation_generator = val_dataset.flow_from_directory(
                    directory='../Dataset_4_classe_second_approach/val/',
                    target_size=(224,224),
                    color_mode="rgb",
                    classes=None,
                    class_mode="categorical",
                    batch_size=32,
                    shuffle=True,
                    seed=1234,
                    save_to_dir=None,
                    save_prefix="",
                    save_format="png",
                    follow_links=False,
                    subset=None,
                    interpolation="nearest")
# Out:
# Found 64 images belonging to 4 classes.

# %%
validation_generator.class_indices
# Out:
# {'Covid': 0, 'NORMAL': 1, 'Pneumocystis': 2, 'Streptococcus': 3}

# %%
classes = pd.DataFrame(train_generator.classes)
classes[0].value_counts(normalize=False)
# Out:
# 2    194
# 3    187
# 1    176
# 0    176
# Name: 0, dtype: int64

# %% [markdown]
# ### Train the CNN model

# %% [markdown]
# #### Now fit the model. But lets add check point so we don't lose the best model.
#
# I used val_accuarcy as important parameters.

# %%
# # inserting the parent directory into current path
# # sys.path.insert(1, '../COVID_19/')
# sys.path.insert(1, '../DeepNet_4_class_classification_Project/')
# # filepath="weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"

# save_filepath = "../Codes/Models/balanced_seconApp__model_4_class_epoch_{epoch:02d}_acc_{accuracy:.2f}_val_acc_{val_accuracy:.2f}_.h5"
# checkpoint = ModelCheckpoint(save_filepath, 
#                              monitor='val_accuracy', 
#                              verbose=1,
#                              save_best_only=False, 
#                              mode='max', 
#                              period=1)

# %%
# inserting the parent directory into current path
# sys.path.insert(1, '../COVID_19/')
sys.path.insert(1, '../DeepNet_4_class_classification_Project/')
# filepath="weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"

save_filepath = "../Codes/Models/balanced_seconApp__model_4_class_epoch_{epoch:02d}_acc_{acc:.2f}_val_acc_{val_acc:.2f}_.h5"
checkpoint = ModelCheckpoint(save_filepath, 
                             monitor='val_acc', 
                             verbose=1,
                             save_best_only=True, 
                             mode='max', 
                             period=1)

# %%
# %%time
model_history = model.fit_generator(
                generator=train_generator, 
                steps_per_epoch=300, 
                epochs=30, 
                verbose=1, 
                validation_data= validation_generator, 
                validation_steps=2, 
                class_weight=None, 
                max_queue_size=10, 
                workers=1, 
                use_multiprocessing=False,
                shuffle=True, 
                initial_epoch=0,
                callbacks=[checkpoint])
# Out:
# WARNING:tensorflow:From /Users/amin/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/30
# 2/2 [==============================] - 4s 2s/step - loss: 1.6487 - acc: 0.2500
#
# Epoch 00001: val_acc improved from -inf to 0.25000, saving model to ../Codes/Models/balanced_seconApp__model_4_class_epoch_01_acc_0.30_val_acc_0.25_.h5
# 23/23 [==============================] - 180s 8s/step - loss: 1.8749 - acc: 0.3029 - val_loss: 1.6487 - val_acc: 0.2500
# Epoch 2/30
# 2/2 [==============================] - 4s 2s/step - loss: 1.5917 - acc: 0.2500
#
# Epoch 00002: val_acc did not improve from 0.25000
# 23/23 [==============================] - 172s 7s/step - loss: 1.4431 - acc: 0.3888 - val_loss: 1.5917 - val_acc: 0.2500
# Epoch 3/30
# 2/2 [==============================] - 4s 2s/step - loss: 1.5436 - acc: 0.2500
#
# Epoch 00003: val_acc did not improve from 0.25000
# 23/23 [==============================] - 170s 7s/step - loss: 1.2382 - acc: 0.4352 - val_loss: 1.5436 - val_acc: 0.2500
# Epoch 4/30
# 2/2 [==============================] - 4s 2s/step - loss: 1.6697 - acc: 0.2500
#
# Epoch 00004: val_acc did not improve from 0.25000
# 23/23 [==============================] - 171s 7s/step - loss: 1.1280 - acc: 0.5116 - val_loss: 1.6697 - val_acc: 0.2500
# Epoch 5/30
# 2/2 [==============================] - 4s 2s/step - loss: 1.4084 - acc: 0.2656
#
# Epoch 00005: val_acc improved from 0.25000 to 0.26562, saving model to ../Codes/Models/balanced_seconApp__model_4_class_epoch_05_acc_0.52_val_acc_0.27_.h5
# 23/23 [==============================] - 174s 8s/step - loss: 1.0653 - acc: 0.5225 - val_loss: 1.4084 - val_acc: 0.2656
# Epoch 6/30
# 2/2 [==============================] - 4s 2s/step - loss: 1.2565 - acc: 0.4688
#
# Epoch 00006: val_acc improved from 0.26562 to 0.46875, saving model to ../Codes/Models/balanced_seconApp__model_4_class_epoch_06_acc_0.57_val_acc_0.47_.h5
# 23/23 [==============================] - 170s 7s/step - loss: 1.0350 - acc: 0.5716 - val_loss: 1.2565 - val_acc: 0.4688
# Epoch 7/30
# 2/2 [==============================] - 4s 2s/step - loss: 1.2426 - acc: 0.4688
#
# Epoch 00007: val_acc did not improve from 0.46875
# 23/23 [==============================] - 169s 7s/step - loss: 0.9991 - acc: 0.5907 - val_loss: 1.2426 - val_acc: 0.4688
# Epoch 8/30
# 2/2 [==============================] - 4s 2s/step - loss: 1.2426 - acc: 0.4844
#
# Epoch 00008: val_acc improved from 0.46875 to 0.48438, saving model to ../Codes/Models/balanced_seconApp__model_4_class_epoch_08_acc_0.63_val_acc_0.48_.h5
# 23/23 [==============================] - 172s 7s/step - loss: 0.9599 - acc: 0.6317 - val_loss: 1.2426 - val_acc: 0.4844
# Epoch 9/30
# 2/2 [==============================] - 4s 2s/step - loss: 1.3919 - acc: 0.3906
#
# Epoch 00009: val_acc did not improve from 0.48438
# 23/23 [==============================] - 169s 7s/step - loss: 0.9397 - acc: 0.5989 - val_loss: 1.3919 - val_acc: 0.3906
# Epoch 10/30
# 2/2 [==============================] - 4s 2s/step - loss: 1.4729 - acc: 0.2188
#
# Epoch 00010: val_acc did not improve from 0.48438
# 23/23 [==============================] - 169s 7s/step - loss: 0.9166 - acc: 0.6194 - val_loss: 1.4729 - val_acc: 0.2188
# Epoch 11/30
# 2/2 [==============================] - 4s 2s/step - loss: 1.6883 - acc: 0.2344
#
# Epoch 00011: val_acc did not improve from 0.48438
# 23/23 [==============================] - 173s 8s/step - loss: 0.8676 - acc: 0.6658 - val_loss: 1.6883 - val_acc: 0.2344
# Epoch 12/30
# 2/2 [==============================] - 4s 2s/step - loss: 1.4434 - acc: 0.2812
#
# Epoch 00012: val_acc did not improve from 0.48438
# 23/23 [==============================] - 177s 8s/step - loss: 0.8741 - acc: 0.6453 - val_loss: 1.4434 - val_acc: 0.2812
# Epoch 13/30
# 2/2 [==============================] - 4s 2s/step - loss: 1.0264 - acc: 0.4531
#
# Epoch 00013: val_acc did not improve from 0.48438
# 23/23 [==============================] - 187s 8s/step - loss: 0.8515 - acc: 0.6480 - val_loss: 1.0264 - val_acc: 0.4531
# Epoch 14/30
# 2/2 [==============================] - 4s 2s/step - loss: 0.8236 - acc: 0.5625
#
# Epoch 00014: val_acc improved from 0.48438 to 0.56250, saving model to ../Codes/Models/balanced_seconApp__model_4_class_epoch_14_acc_0.67_val_acc_0.56_.h5
# 23/23 [==============================] - 174s 8s/step - loss: 0.8588 - acc: 0.6671 - val_loss: 0.8236 - val_acc: 0.5625
# Epoch 15/30
# 2/2 [==============================] - 4s 2s/step - loss: 1.1141 - acc: 0.3750
#
# Epoch 00015: val_acc did not improve from 0.56250
# 23/23 [==============================] - 190s 8s/step - loss: 0.8363 - acc: 0.6562 - val_loss: 1.1141 - val_acc: 0.3750
# Epoch 16/30
# 2/2 [==============================] - 4s 2s/step - loss: 0.5735 - acc: 0.7969
#
# Epoch 00016: val_acc improved from 0.56250 to 0.79688, saving model to ../Codes/Models/balanced_seconApp__model_4_class_epoch_16_acc_0.66_val_acc_0.80_.h5
# 23/23 [==============================] - 187s 8s/step - loss: 0.8074 - acc: 0.6630 - val_loss: 0.5735 - val_acc: 0.7969
# Epoch 17/30
# 2/2 [==============================] - 4s 2s/step - loss: 0.5909 - acc: 0.7812
#
# Epoch 00017: val_acc did not improve from 0.79688
# 23/23 [==============================] - 177s 8s/step - loss: 1.0619 - acc: 0.6194 - val_loss: 0.5909 - val_acc: 0.7812
# Epoch 18/30
# 2/2 [==============================] - 4s 2s/step - loss: 0.7770 - acc: 0.6875
#
# Epoch 00018: val_acc did not improve from 0.79688
# 23/23 [==============================] - 181s 8s/step - loss: 0.7879 - acc: 0.6739 - val_loss: 0.7770 - val_acc: 0.6875
# Epoch 19/30
# 2/2 [==============================] - 4s 2s/step - loss: 0.6855 - acc: 0.7031
#
# Epoch 00019: val_acc did not improve from 0.79688
# 23/23 [==============================] - 177s 8s/step - loss: 0.7664 - acc: 0.6917 - val_loss: 0.6855 - val_acc: 0.7031
# Epoch 20/30
# 2/2 [==============================] - 4s 2s/step - loss: 0.8354 - acc: 0.6094
#
# Epoch 00020: val_acc did not improve from 0.79688
# 23/23 [==============================] - 177s 8s/step - loss: 0.7793 - acc: 0.6876 - val_loss: 0.8354 - val_acc: 0.6094
# Epoch 21/30
# 2/2 [==============================] - 4s 2s/step - loss: 0.7369 - acc: 0.6406
#
# Epoch 00021: val_acc did not improve from 0.79688
# 23/23 [==============================] - 174s 8s/step - loss: 0.7643 - acc: 0.6835 - val_loss: 0.7369 - val_acc: 0.6406
# Epoch 22/30
# 2/2 [==============================] - 4s 2s/step - loss: 0.5896 - acc: 0.7344
#
# Epoch 00022: val_acc did not improve from 0.79688
# 23/23 [==============================] - 175s 8s/step - loss: 0.7923 - acc: 0.6698 - val_loss: 0.5896 - val_acc: 0.7344
# Epoch 23/30
# 2/2 [==============================] - 4s 2s/step - loss: 0.5833 - acc: 0.7656
#
# Epoch 00023: val_acc did not improve from 0.79688
# 23/23 [==============================] - 175s 8s/step - loss: 0.7303 - acc: 0.6985 - val_loss: 0.5833 - val_acc: 0.7656
# Epoch 24/30
# 2/2 [==============================] - 4s 2s/step - loss: 0.5314 - acc: 0.8281
#
# Epoch 00024: val_acc improved from 0.79688 to 0.82812, saving model to ../Codes/Models/balanced_seconApp__model_4_class_epoch_24_acc_0.69_val_acc_0.83_.h5
# 23/23 [==============================] - 173s 8s/step - loss: 0.7436 - acc: 0.6930 - val_loss: 0.5314 - val_acc: 0.8281
# Epoch 25/30
# 2/2 [==============================] - 4s 2s/step - loss: 0.5166 - acc: 0.8125
#
# Epoch 00025: val_acc did not improve from 0.82812
# 23/23 [==============================] - 178s 8s/step - loss: 0.7544 - acc: 0.6889 - val_loss: 0.5166 - val_acc: 0.8125
# Epoch 26/30
# 2/2 [==============================] - 4s 2s/step - loss: 0.5326 - acc: 0.7812
#
# Epoch 00026: val_acc did not improve from 0.82812
# 23/23 [==============================] - 174s 8s/step - loss: 0.7295 - acc: 0.7040 - val_loss: 0.5326 - val_acc: 0.7812
# Epoch 27/30
# 2/2 [==============================] - 4s 2s/step - loss: 0.5192 - acc: 0.7969
#
# Epoch 00027: val_acc did not improve from 0.82812
# 23/23 [==============================] - 171s 7s/step - loss: 0.7261 - acc: 0.6889 - val_loss: 0.5192 - val_acc: 0.7969
# Epoch 28/30
# 2/2 [==============================] - 4s 2s/step - loss: 0.4924 - acc: 0.8438
#
# Epoch 00028: val_acc improved from 0.82812 to 0.84375, saving model to ../Codes/Models/balanced_seconApp__model_4_class_epoch_28_acc_0.73_val_acc_0.84_.h5
# 23/23 [==============================] - 173s 8s/step - loss: 0.6783 - acc: 0.7285 - val_loss: 0.4924 - val_acc: 0.8438
# Epoch 29/30
# 2/2 [==============================] - 5s 2s/step - loss: 0.5063 - acc: 0.8125
#
# Epoch 00029: val_acc did not improve from 0.84375
# 23/23 [==============================] - 179s 8s/step - loss: 0.7020 - acc: 0.7408 - val_loss: 0.5063 - val_acc: 0.8125
# Epoch 30/30
# 2/2 [==============================] - 5s 2s/step - loss: 0.5534 - acc: 0.8594
#
# Epoch 00030: val_acc improved from 0.84375 to 0.85938, saving model to ../Codes/Models/balanced_seconApp__model_4_class_epoch_30_acc_0.73_val_acc_0.86_.h5
# 23/23 [==============================] - 182s 8s/step - loss: 0.6922 - acc: 0.7340 - val_loss: 0.5534 - val_acc: 0.8594
# CPU times: user 7h 38min 37s, sys: 1h 44min 35s, total: 9h 23min 12s
# Wall time: 1h 27min 48s

# %% [markdown]
# ### Plot the History

# %%
# list all data in history
print('len(model_history.history.keys()) \n', len(model_history.history.keys()),'\n')
print(model_history.history.keys())
# Out:
# len(model_history.history.keys())
#  4
#
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
model_history_df = pd.DataFrame(model_history.history)
model_history_df
# Out:
#         loss       acc  val_loss   val_acc
# 0   1.874424  0.302865  1.648677  0.250000
# 1   1.443413  0.388813  1.591683  0.250000
# 2   1.237580  0.435198  1.543604  0.250000
# 3   1.128528  0.511596  1.669653  0.250000
# 4   1.064629  0.522510  1.408352  0.265625
# 5   1.034133  0.571623  1.256485  0.468750
# 6   0.998645  0.590723  1.242572  0.468750
# 7   0.959336  0.631651  1.242632  0.484375
# 8   0.938563  0.598909  1.391862  0.390625
# 9   0.916580  0.619372  1.472942  0.218750
# 10  0.866310  0.665757  1.688342  0.234375
# 11  0.873826  0.645293  1.443385  0.281250
# 12  0.851713  0.648022  1.026426  0.453125
# 13  0.859020  0.667121  0.823553  0.562500
# 14  0.836351  0.656207  1.114052  0.375000
# 15  0.806270  0.663029  0.573482  0.796875
# 16  1.048921  0.619372  0.590854  0.781250
# 17  0.788492  0.673943  0.777040  0.687500
# 18  0.766627  0.691678  0.685518  0.703125
# 19  0.780487  0.687585  0.835427  0.609375
# 20  0.764921  0.683492  0.736917  0.640625
# 21  0.792813  0.669850  0.589646  0.734375
# 22  0.730193  0.698499  0.583336  0.765625
# 23  0.744050  0.693042  0.531371  0.828125
# 24  0.753086  0.688950  0.516600  0.812500
# 25  0.728053  0.703956  0.532559  0.781250
# 26  0.725802  0.688950  0.519247  0.796875
# 27  0.678454  0.728513  0.492410  0.843750
# 28  0.700425  0.740791  0.506334  0.812500
# 29  0.692382  0.733970  0.553358  0.859375

# %%
model_history_df.columns
# Out:
# Index(['loss', 'acc', 'val_loss', 'val_acc'], dtype='object')

# %%
plt.figure(figsize=(15,17))
# columns = ['loss', 'accuracy', 'mse', 'auc', 'true_positives', 'true_negatives',
#            'false_positives', 'false_negatives']
# columns = ['loss', 'accuracy']
columns = ['loss', 'acc']
for i,col in enumerate(columns):
    
    plt.subplot(3, 3, i+1)
    
    plt.plot(model_history_df[col])
    plt.plot(model_history_df['val_'+col], color='red')
    plt.title('model '+col)
    plt.ylabel(col)
    plt.xlabel('epoch')
    plt.legend(['train', 'val'])
plt.savefig("../Figures/plot_01_1_4classes_balanced_second_app.png")
# plt.savefig("../Figures/plot_01_1_4classes.png")

# %%
# model.save("../Codes/Models/model_covid_test_4classes_82percent.h5")
