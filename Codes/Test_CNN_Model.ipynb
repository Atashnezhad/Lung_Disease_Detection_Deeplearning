# %%
import pandas as pd
import os
import shutil
import sys
import warnings
warnings.filterwarnings('ignore')
from collections import Counter

import numpy as np
import matplotlib.pyplot as plt
# import tensorflow as tf
from tensorflow import keras
import tensorflow


import tensorflow as tf

from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

# %%
# inserting the parent directory into current path
# sys.path.insert(1, '../COVID_19/')
sys.path.insert(1, '../DeepNet_4_class_classification_Project/')

# %%
# path_1 = 'C:/Users/DASLAB Hareland 3/Desktop/COVID_19/Codes/Models/model_covid_test_4classes_82percent.h5'
path_1 = '../Codes/Models/model_4_class-06-0.88checkpoint.h5'

# %%
model = keras.models.load_model(path_1)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# batch_normalization_v1 (Batc (None, 222, 222, 32)      128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 220, 220, 64)      18496
# _________________________________________________________________
# batch_normalization_v1_1 (Ba (None, 220, 220, 64)      256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 110, 110, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 64)      36928
# _________________________________________________________________
# batch_normalization_v1_2 (Ba (None, 108, 108, 64)      256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 52, 52, 64)        36928
# _________________________________________________________________
# batch_normalization_v1_3 (Ba (None, 52, 52, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# batch_normalization_v1_4 (Ba (None, 24, 24, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                1179712
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 1,348,484
# Trainable params: 1,347,780
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# #### Read Image and predit using the CNN model.

# %% [markdown]
# # Normal

# %%
path_to_img = '../Codes/Models/Test_Data_Set/NORMAL/Normal_google.jpeg'

#Input shape to the model is 224 x 224. SO resize input image to this shape.
from tensorflow.keras.preprocessing.image import load_img, img_to_array
img = load_img(path_to_img, target_size=(224, 224)) #VGG user 224 as input
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FE67222D978>

# %%
# convert the image to an array
img = img_to_array(img)
# expand dimensions to match the shape of model input
img = np.expand_dims(img, axis=0)

# Generate feature output by predicting on the input image
feature_output = model.predict(img)
feature_output
# Out:
# array([[0.26171467, 0.07483014, 0.4338684 , 0.22958682]], dtype=float32)

# %% [markdown]
# # Covid

# %%
path_to_img = '../Codes/Models/Test_Data_Set/COVID/Covid_google.jpeg'

#Input shape to the model is 224 x 224. SO resize input image to this shape.
from tensorflow.keras.preprocessing.image import load_img, img_to_array
img = load_img(path_to_img, target_size=(224, 224)) #VGG user 224 as input
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FE682B59320>

# %%
# convert the image to an array
img = img_to_array(img)
# expand dimensions to match the shape of model input
img = np.expand_dims(img, axis=0)

# Generate feature output by predicting on the input image
feature_output = model.predict(img)
feature_output
# Out:
# array([[0.2603404 , 0.07218315, 0.43518803, 0.23228835]], dtype=float32)

# %% [markdown]
# # Streptococcus

# %%
path_to_img = '../Codes/Models/Test_Data_Set/Streptococcus_google/Streptococcus_google.jpeg'

#Input shape to the model is 224 x 224. SO resize input image to this shape.
from tensorflow.keras.preprocessing.image import load_img, img_to_array
img = load_img(path_to_img, target_size=(224, 224)) #VGG user 224 as input
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FE684AA1400>

# %%
# convert the image to an array
img = img_to_array(img)
# expand dimensions to match the shape of model input
img = np.expand_dims(img, axis=0)

# Generate feature output by predicting on the input image
feature_output = model.predict(img)
feature_output
# Out:
# array([[0.2787655 , 0.06259773, 0.41045746, 0.2481793 ]], dtype=float32)

# %% [markdown]
# # Pneumocystis

# %%
path_to_img = '../Codes/Models/Test_Data_Set/Pneumocystis_google/Pneumocystis_google.jpeg'

#Input shape to the model is 224 x 224. SO resize input image to this shape.
from tensorflow.keras.preprocessing.image import load_img, img_to_array
img = load_img(path_to_img, target_size=(224, 224)) #VGG user 224 as input
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FE681950828>

# %%
# convert the image to an array
img = img_to_array(img)
# expand dimensions to match the shape of model input
img = np.expand_dims(img, axis=0)

# Generate feature output by predicting on the input image
feature_output = model.predict(img)
feature_output
# Out:
# array([[0.25325108, 0.07562745, 0.44471633, 0.2264051 ]], dtype=float32)
